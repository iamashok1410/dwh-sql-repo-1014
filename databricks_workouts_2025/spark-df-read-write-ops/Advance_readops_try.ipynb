# %%
struct1="custid int,name string,age int,corrupt_record string"
df1=spark.read.schema(struct1).csv("/Volumes/catalog1_dropme/schema1_dropme/volume1_dropme/directory_dropme/malformeddata1.txt",header=False,sep=',',mode='permissive',comment='#',columnNameOfCorruptRecord="corrupt_record",quote="'",escape="|")
df1.show(10,False)

# %%
from pyspark.sql.functions import *
struct1="custid int,name string,height float,joindt date,age string"
df1=spark.read.schema(struct1).csv("/Volumes/catalog1_dropme/schema1_dropme/volume1_dropme/directory_dropme/malformeddata1.txt",header=False,mode='permissive'
                                   ,multiLine=True,quote="'",ignoreLeadingWhiteSpace=True,ignoreTrailingWhiteSpace=True,
                                   nullValue='na',nanValue=-1,maxCharsPerColumn='100',comment='#',modifiedAfter='2025-12-19',dateFormat="yyyy-dd-MM")
display(df1)

# %%
struct1="custid int,name string,age int,corrupt_record string"
df2=spark.read.schema(struct1).csv("/Volumes/catalog1_dropme/schema1_dropme/volume1_dropme/directory_dropme/malformeddata.txt",header=False,sep=',',mode='permissive',comment='#',columnNameOfCorruptRecord="corrupt_record",quote="'")
df2.show(10)
display(df2)
print(df2.count())

df1=spark.read.schema(struct1).csv("/Volumes/catalog1_dropme/schema1_dropme/volume1_dropme/directory_dropme/malformeddata.txt",header=False,sep=',',mode='dropMalformed',comment='#',columnNameOfCorruptRecord="corrupt_record",quote="'")
df1.show(10)

df1=spark.read.schema(struct1).csv("/Volumes/catalog1_dropme/schema1_dropme/volume1_dropme/directory_dropme/malformeddata.txt",header=False,sep=',',mode='failFast',comment='#',columnNameOfCorruptRecord="corrupt_record",quote="'")
df1.show(10)

# %%
str1="id int,name string,amt float,dop date,corruptrecord string"
dfjson1=spark.read.schema(str1).json("/Volumes/catalog1_dropme/schema1_dropme/volume1_dropme/directory_dropme/",samplingRatio=1,allowUnquotedFieldNames=True,allowSingleQuotes=True,modifiedAfter='2025-12-26',dateFormat='yyyy-dd-MM',columnNameOfCorruptRecord="corruptrecord",pathGlobFilter="simple_json.tx*",recursiveFileLookup=True)
dfjson1.printSchema()
dfjson1.show(10,False)

# %%
str1="id int,name string,amt float,dop date,corruptrecord string"
dfjson1=spark.read.schema(str1).json("/Volumes/catalog1_dropme/schema1_dropme/volume1_dropme/directory_dropme/",allowUnquotedFieldNames=True,allowSingleQuotes=True,modifiedAfter='2025-12-22',dateFormat='yyyy-dd-MM',columnNameOfCorruptRecord="corruptrecord",pathGlobFilter="simple_json2.tx*",recursiveFileLookup=True,
                                     allowComments=True,lineSep='~',useUnsafeRow=True)
dfjson1.printSchema()
dfjson1.show(10,False)

# %%
str1="id int,name string,amt float,dop date,corruptrecord string"
dfjson1=spark.read.schema(str1).json("/Volumes/catalog1_dropme/schema1_dropme/volume1_dropme/directory_dropme/simple_json_multiline3.txt",dateFormat='yyyy-dd-MM',columnNameOfCorruptRecord="corruptrecord",
                                     allowComments=True,multiLine=True)
dfjson1.printSchema()
dfjson1.show(10,False)

# %%
dbutils.fs.mv("/Volumes/workspace/default/volumewd36/day1_op" , "/Volumes/workspace/default/volumewd36/orcop", True)

# %%
day1df=spark.read.csv("/Volumes/catalog1_dropme/schema1_dropme/volume1_dropme/directory_dropme/source1.txt",header=True,inferSchema=True)
day1df.show(5)
#day1df.write.orc("/Volumes/workspace/default/volumewd36/day1_op/",mode='append')
day1df=spark.read.orc("/Volumes/workspace/default/volumewd36/orcop/")
day1df=day1df.dropDuplicates(["id"])
display(day1df)

day2df=spark.read.csv("/Volumes/catalog1_dropme/schema1_dropme/volume1_dropme/directory_dropme/source2.txt",header=True,inferSchema=True)
#day2df.write.orc("/Volumes/workspace/default/volumewd36/orcop/",mode='append')
day2df.show(10)

day3df=spark.read.csv("/Volumes/catalog1_dropme/schema1_dropme/volume1_dropme/directory_dropme/source3.txt",header=True,inferSchema=True)
#day3df.write.orc("/Volumes/workspace/default/volumewd36/orcop/",mode='append')
display(day3df)
display(day1df)

# %%
post_day3=spark.read.orc("/Volumes/workspace/default/volumewd36/orcop/",mergeSchema=True)
display(post_day3)
